# %%
# import PIL
from PIL import Image
import numpy as np

# %%
def toOpenImage(img_name) :
    ### ...load one image on 'im' variable...
    img = Image.open(img_name)

    ### ...showing image...
    #im.show()

    ### ...reading size...
    width, height = img.size
    #print('width: ', width, '  ', 'height: ', height)
    #print( type(im) )

    ### ...loading pixels values...
    pix = img.load()
    # print(pix)
    # print( type(pix) )

    # ...reading one row of pixels...
    # pix_row = 0
    # print(im.size[0])
    # print(im.size[1])
    
    return width, height, pix
# Out:
# width:  29    height:  30
# <class 'PIL.PpmImagePlugin.PpmImageFile'>
# ...
# <class 'PixelAccess'>
# 29
# 30
# ...

# %%
def toConvertBn(img_bn):
    img_bn = im.convert("L")
    # img_bn.show()
    pix_bn = img_bn.load()


    # for i in range(0,width):
    #    print(i, '   ', pix_bn[i,0], '   ', len(pix_bn[i,0]) )

    # ...with that I get the list with pixels data...
    print( list(img_bn.getdata()) )

# %%
img = imgToOpen("00000_00000.ppm")
toConvertBn(img_bn)
